# %% [markdown]
# # Baseline Model

# %%
# Importing required libraries for model building and evaluation
import sys
sys.path.append("../src")
import pandas as pd
from models import train_baseline_model

# %%
# Load Processed Data
df = pd.read_csv("../data/featured_data.csv")

# Calling the baseline model function which:
# - Trains the Logistic Regression model
# - Splits the data into training and testing sets
# - Generates predicted probabilities for evaluation
# It returns the trained model along with test data and prediction scores
model, X_test, y_test, y_prob = train_baseline_model(df)

# %%
# Saving the trained baseline model to a file so it can be reused later
# This avoids retraining the model every time we run the project

import pickle
pickle.dump(model, open("../models/baseline_model.pkl", "wb"))
print("Baseline Working Properly!✅")
# Out:
# Baseline Working Properly!✅
