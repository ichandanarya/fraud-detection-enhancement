# %%
import sys
sys.path.append("../src")

# Importing required libraries
import pandas as pd
from models import train_xgb_model  # Importing function to train XGBoost model

# Loading the feature-engineered dataset
df = pd.read_csv("../data/featured_data.csv")

# Calling the function that:
# - trains the XGBoost model
# - splits data into train/test
# - returns test data and prediction probabilities for evaluation
model, X_test, y_test, y_prob = train_xgb_model(df)

# Saving the trained model to a file so it can be reused later without retraining
import pickle
pickle.dump(model, open("../models/fraud_model.pkl", "wb"))

# Printing confirmation message to ensure the model was trained and saved successfully
print("fraud_model Working Properly!✅")
