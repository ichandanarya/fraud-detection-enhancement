# %% [markdown]
# # Data Preprocessing

# %%
import sys
sys.path.append("../src")

# %% [markdown]
# ##  Importing necessary libraries for data handling and preprocessing

# %%
import pandas as pd
from preprocessing import preprocess_data

# %%
# Loading dataset from the data folder
df = pd.read_csv("../data/creditcard.csv")
df = preprocess_data(df)

# Saving processed data for reuse in later steps (feature engineering / modeling)
df.to_csv("../data/processed_data.csv", index=False)
df.head()
