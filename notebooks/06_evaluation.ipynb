# %%
import sys
sys.path.append("../src")

# Importing required libraries and evaluation functions
import pandas as pd
from models import evaluate_model, ks_statistic

# Loading the feature-engineered dataset
df = pd.read_csv("../data/featured_data.csv")

# Importing the function to train the XGBoost model
from models import train_xgb_model

# Training the model and getting:
# - test dataset
# - actual labels
# - predicted probabilities for evaluation
model, X_test, y_test, y_prob = train_xgb_model(df)

# Evaluating model performance using metrics like ROC-AUC, classification report, etc.
evaluate_model(y_test, y_prob)

# Calculating KS statistic to measure how well the model separates fraud and non-fraud cases
print("KS Score:", ks_statistic(y_test, y_prob))
# Out:
# C:\Users\chandan arya\AppData\Roaming\Python\Python312\site-packages\xgboost\training.py:183: UserWarning: [08:54:21] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# ROC-AUC: 0.9735902274528269
# KS Score: 0.9176197701928267
